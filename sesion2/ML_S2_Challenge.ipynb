# %% [markdown]
# # **AISaturdays Rental Challenge**
#
# ![AISaturdays](https://www.saturdays.ai/assets/images/ai-saturdays-122x122.png)
#
# Bienvenido al reto de **AISaturdays** de Inteligencia Artificial para la predicción de precios de rentals de los barrios de una ciudad. En este ejercicio estimaremos el precio de una oferta de alquiler, dependiendo de unos datos descritos más abajo.
#
# **Instrucciones:**
#
# - Se usará el lenguaje de programación Python 3.
# - Se usarán las librerías de python: Pandas, MatPlotLib, Numpy.
#
# **Mediante este ejercicio, aprenderemos:**
# - Entender y ejecutar los NoteBooks con Python.
# - Ser capaz de utilizar funciones de Python y librerías adicionales.
# - Dataset:
#  - Obtener el dataset y previsualizar la información del dataset.
#  - Limpiar y normalizar la información del dataset.
#  - Representar y analizar la información del dataset.
# - Aplicar el algoritmo de Random Forest
# - Mejorar la predicción usando Hyperparameter Tunning, Feature engineering y Gradient Boosting
#
# ¡Empecemos!

# %% [markdown]
# #1.Importación de librerias

# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import statsmodels.api as sm
import scipy.stats as stats

# %% [markdown]
# #2. Dataset

# %% [markdown]
# 0. Lee el .csv con los datos y muestra las primeras filas.

# %%
#Dos lineas de código
data = pd.read_csv('data.csv')
data.transpose().head(20)
# Out:
#                                                0      \
# Unnamed: 0                                     35706
# id                                          28341280
# name                            Bushwick Rustic Loft
# host_id                                     10812370
# host_name                                         Al
# neighbourhood_group                         Brooklyn
# neighbourhood                               Bushwick
# latitude                                     40.6999
# longitude                                   -73.9182
# room_type                               Private room
# minimum_nights                                     1
# number_of_reviews                                 28
# last_review                               2019-07-07
# reviews_per_month                               2.75
# calculated_host_listings_count                     1
# availability_365                                  36
# price                                             69
#
#                                                               1      \
# Unnamed: 0                                                     2434
# id                                                          1213991
# name                            Private 2 bedroom Midtown Manhattan
# host_id                                                     6626827
# host_name                                                     Steve
# neighbourhood_group                                       Manhattan
# neighbourhood                                        Hell's Kitchen
# latitude                                                    40.7625
# longitude                                                  -73.9929
# room_type                                              Private room
# minimum_nights                                                    4
# number_of_reviews                                                77
# last_review                                              2019-06-19
# reviews_per_month                                              1.81
# calculated_host_listings_count                                    1
# availability_365                                                 21
# price                                                           240
#
#                                                        2      \
# Unnamed: 0                                             44725
# id                                                  34372753
# name                            Spacious Manhattan Apartment
# host_id                                             40038018
# host_name                                               Yves
# neighbourhood_group                                Manhattan
# neighbourhood                                        Midtown
# latitude                                             40.7615
# longitude                                           -73.9718
# room_type                                    Entire home/apt
# minimum_nights                                             5
# number_of_reviews                                          2
# last_review                                       2019-06-09
# reviews_per_month                                          1
# calculated_host_listings_count                             1
# availability_365                                         132
# price                                                    449
#
#                                                                        3      \
# Unnamed: 0                                                             32341
# id                                                                  25311295
# name                            ★Modern,Cozy 3BDR/2BA Getaway in Upper East!
# host_id                                                             17896706
# host_name                                                               Mark
# neighbourhood_group                                                Manhattan
# neighbourhood                                                Upper East Side
# latitude                                                             40.7799
# longitude                                                           -73.9548
# room_type                                                    Entire home/apt
# minimum_nights                                                             4
# number_of_reviews                                                         58
# last_review                                                       2019-06-18
# reviews_per_month                                                       4.26
# calculated_host_listings_count                                             1
# availability_365                                                         158
# price                                                                    399
#
#                                                                        4      \
# Unnamed: 0                                                              9648
# id                                                                   7411421
# name                            Hip & Trendy Williamsburg 2 BR 2BA Apartment
# host_id                                                              3750905
# host_name                                                              Louis
# neighbourhood_group                                                 Brooklyn
# neighbourhood                                                   Williamsburg
# latitude                                                              40.713
# longitude                                                           -73.9558
# room_type                                                    Entire home/apt
# minimum_nights                                                             2
# number_of_reviews                                                         28
# last_review                                                       2019-06-22
# reviews_per_month                                                       0.61
# calculated_host_listings_count                                             1
# availability_365                                                         170
# price                                                                    109
#
#                                                               5      \
# Unnamed: 0                                                    44884
# id                                                         34447529
# name                            Cozy UWS Studio Near Riverside Park
# host_id                                                   260046126
# host_name                                                     Morad
# neighbourhood_group                                       Manhattan
# neighbourhood                                       Upper West Side
# latitude                                                    40.7896
# longitude                                                  -73.9794
# room_type                                           Entire home/apt
# minimum_nights                                                    1
# number_of_reviews                                                 2
# last_review                                              2019-06-30
# reviews_per_month                                              1.33
# calculated_host_listings_count                                    1
# availability_365                                                346
# price                                                           165
#
#                                                                            6      \
# Unnamed: 0                                                                 38355
# id                                                                      30205007
# name                            Quaint 1 bedroom tenement apartment in E.Village
# host_id                                                                 72326431
# host_name                                                                Brianna
# neighbourhood_group                                                    Manhattan
# neighbourhood                                                       East Village
# latitude                                                                 40.7257
# longitude                                                               -73.9884
# room_type                                                        Entire home/apt
# minimum_nights                                                                 2
# number_of_reviews                                                             11
# last_review                                                           2019-06-29
# reviews_per_month                                                           1.47
# calculated_host_listings_count                                                 1
# availability_365                                                             102
# price                                                                        100
#
#                                                           7      \
# Unnamed: 0                                                18184
# id                                                     14237346
# name                            Cozy room at Brooklyn&Breakfast
# host_id                                                  344035
# host_name                        Brooklyn&   Breakfast    -Len-
# neighbourhood_group                                    Brooklyn
# neighbourhood                                  Prospect Heights
# latitude                                                40.6782
# longitude                                              -73.9697
# room_type                                          Private room
# minimum_nights                                                1
# number_of_reviews                                           102
# last_review                                          2019-06-27
# reviews_per_month                                          2.98
# calculated_host_listings_count                               13
# availability_365                                            281
# price                                                        55
#
#                                                           8      \
# Unnamed: 0                                                12800
# id                                                      9775397
# name                            Apartment at the St.Regis Hotel
# host_id                                                50397134
# host_name                                              Masaichi
# neighbourhood_group                                   Manhattan
# neighbourhood                                           Midtown
# latitude                                                 40.761
# longitude                                              -73.9751
# room_type                                       Entire home/apt
# minimum_nights                                                1
# number_of_reviews                                             0
# last_review                                                 NaN
# reviews_per_month                                           NaN
# calculated_host_listings_count                                1
# availability_365                                              0
# price                                                      1200
#
#                                                      9      ...  \
# Unnamed: 0                                           37069  ...
# id                                                29472696  ...
# name                            Sharing room for FEMALE #1  ...
# host_id                                          167620568  ...
# host_name                                          Mikosya  ...
# neighbourhood_group                               Brooklyn  ...
# neighbourhood                               Brighton Beach  ...
# latitude                                           40.5806  ...
# longitude                                         -73.9631  ...
# room_type                                      Shared room  ...
# minimum_nights                                           1  ...
# number_of_reviews                                        4  ...
# last_review                                     2019-06-09  ...
# reviews_per_month                                     0.56  ...
# calculated_host_listings_count                           2  ...
# availability_365                                       365  ...
# price                                                  100  ...
#
#                                                                 32749  \
# Unnamed: 0                                                      47191
# id                                                           35618939
# name                            NYC private room super clean and cozy
# host_id                                                      83132880
# host_name                                                    Alyandry
# neighbourhood_group                                            Queens
# neighbourhood                                                 Maspeth
# latitude                                                      40.7395
# longitude                                                     -73.895
# room_type                                                Private room
# minimum_nights                                                      1
# number_of_reviews                                                   0
# last_review                                                       NaN
# reviews_per_month                                                 NaN
# calculated_host_listings_count                                      4
# availability_365                                                  304
# price                                                              56
#
#                                                                       32750  \
# Unnamed: 0                                                            21962
# id                                                                 17669480
# name                            Sunny Brownstone Studio in BedStuy Brooklyn
# host_id                                                           112814443
# host_name                                                             Jamal
# neighbourhood_group                                                Brooklyn
# neighbourhood                                            Bedford-Stuyvesant
# latitude                                                            40.6822
# longitude                                                          -73.9462
# room_type                                                   Entire home/apt
# minimum_nights                                                            2
# number_of_reviews                                                       104
# last_review                                                      2019-06-12
# reviews_per_month                                                      3.69
# calculated_host_listings_count                                            1
# availability_365                                                        268
# price                                                                   125
#
#                                                                32751  \
# Unnamed: 0                                                     37194
# id                                                          29547314
# name                            Apartment New York \nHell’s Kitchens
# host_id                                                     35303743
# host_name                                                   Patricia
# neighbourhood_group                                        Manhattan
# neighbourhood                                        Upper West Side
# latitude                                                     40.7683
# longitude                                                   -73.9837
# room_type                                               Private room
# minimum_nights                                                    30
# number_of_reviews                                                  0
# last_review                                                      NaN
# reviews_per_month                                                NaN
# calculated_host_listings_count                                     1
# availability_365                                                  97
# price                                                           6500
#
#                                                             32752  \
# Unnamed: 0                                                  16850
# id                                                       13431257
# name                            Luxurious 1BR Apt in Midtown West
# host_id                                                  30283594
# host_name                                                    Kara
# neighbourhood_group                                     Manhattan
# neighbourhood                                      Hell's Kitchen
# latitude                                                   40.761
# longitude                                                -73.9975
# room_type                                         Entire home/apt
# minimum_nights                                                 30
# number_of_reviews                                               0
# last_review                                                   NaN
# reviews_per_month                                             NaN
# calculated_host_listings_count                                121
# availability_365                                              365
# price                                                         239
#
#                                                      32753  \
# Unnamed: 0                                            6265
# id                                                 4576206
# name                            Brooklyn Brownstone Beauty
# host_id                                           22017065
# host_name                                    Marycatherine
# neighbourhood_group                               Brooklyn
# neighbourhood                             Prospect Heights
# latitude                                           40.6814
# longitude                                         -73.9708
# room_type                                  Entire home/apt
# minimum_nights                                           3
# number_of_reviews                                       27
# last_review                                     2019-07-05
# reviews_per_month                                     0.49
# calculated_host_listings_count                           1
# availability_365                                       266
# price                                                  250
#
#                                                    32754  \
# Unnamed: 0                                         11284
# id                                               8754339
# name                            Gran Fondo Cyclist Haven
# host_id                                         20261309
# host_name                                          Sarah
# neighbourhood_group                            Manhattan
# neighbourhood                         Washington Heights
# latitude                                         40.8465
# longitude                                       -73.9432
# room_type                                    Shared room
# minimum_nights                                         1
# number_of_reviews                                      0
# last_review                                          NaN
# reviews_per_month                                    NaN
# calculated_host_listings_count                         1
# availability_365                                       0
# price                                                 60
#
#                                                                     32755  \
# Unnamed: 0                                                          44732
# id                                                               34383329
# name                            A private bedroom in Chelsea , Manhattan.
# host_id                                                          53254710
# host_name                                                          Aamito
# neighbourhood_group                                             Manhattan
# neighbourhood                                                     Chelsea
# latitude                                                          40.7396
# longitude                                                        -74.0008
# room_type                                                    Private room
# minimum_nights                                                          2
# number_of_reviews                                                       4
# last_review                                                    2019-06-30
# reviews_per_month                                                     1.9
# calculated_host_listings_count                                          1
# availability_365                                                       76
# price                                                                  85
#
#                                                                             32756  \
# Unnamed: 0                                                                  38158
# id                                                                       30109697
# name                            Nicely appointed BIG one bedroom off Central Park
# host_id                                                                   1385157
# host_name                                                                   Brian
# neighbourhood_group                                                     Manhattan
# neighbourhood                                                     Upper West Side
# latitude                                                                  40.7832
# longitude                                                                -73.9737
# room_type                                                         Entire home/apt
# minimum_nights                                                                 30
# number_of_reviews                                                               1
# last_review                                                            2019-04-12
# reviews_per_month                                                            0.34
# calculated_host_listings_count                                                  5
# availability_365                                                              261
# price                                                                         130
#
#                                                            32757  \
# Unnamed: 0                                                   860
# id                                                        304799
# name                            Penthouse Studio by Central Park
# host_id                                                   185753
# host_name                                                Carolyn
# neighbourhood_group                                    Manhattan
# neighbourhood                                    Upper West Side
# latitude                                                 40.7751
# longitude                                               -73.9799
# room_type                                        Entire home/apt
# minimum_nights                                                 2
# number_of_reviews                                             11
# last_review                                           2019-06-09
# reviews_per_month                                           0.13
# calculated_host_listings_count                                 1
# availability_365                                               2
# price                                                        150
#
#                                                         32758
# Unnamed: 0                                              15795
# id                                                   12775106
# name                            Apartment NYC - 10 to 20 June
# host_id                                               1722054
# host_name                                            Cristian
# neighbourhood_group                                    Queens
# neighbourhood                                Long Island City
# latitude                                              40.7466
# longitude                                            -73.9455
# room_type                                     Entire home/apt
# minimum_nights                                              5
# number_of_reviews                                           1
# last_review                                        2016-06-19
# reviews_per_month                                        0.03
# calculated_host_listings_count                              1
# availability_365                                            0
# price                                                     120
#
# [17 rows x 32759 columns]

# %% [markdown]
# 1. Muestra el numero de features y ejemplos en el dataset.

# %%
# Sólo con una línea de código
# Mostrar número de filas y columnas del dataframe
print("Filas: " + str(data.shape[0]) + " Cols: " + str(data.shape[1]))
# Out:
# Filas: 32759 Cols: 17

# %% [markdown]
# 2. Obtén que tipos de datos (dtypes) contiene el dataset.

# %%
# Sólo con una línea de código
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32759 entries, 0 to 32758
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Unnamed: 0                      32759 non-null  int64
#  1   id                              32759 non-null  int64
#  2   name                            32755 non-null  object
#  3   host_id                         32759 non-null  int64
#  4   host_name                       32742 non-null  object
#  5   neighbourhood_group             32759 non-null  object
#  6   neighbourhood                   32759 non-null  object
#  7   latitude                        32759 non-null  float64
#  8   longitude                       32759 non-null  float64
#  9   room_type                       32759 non-null  object
#  10  minimum_nights                  32759 non-null  int64
#  11  number_of_reviews               32759 non-null  int64
#  12  last_review                     25987 non-null  object
#  13  reviews_per_month               25987 non-null  float64
#  14  calculated_host_listings_count  32759 non-null  int64
#  15  availability_365                32759 non-null  int64
#  16  price                           32759 non-null  int64
# dtypes: float64(3), int64(8), object(6)
# memory usage: 4.2+ MB

# %% [markdown]
# ### Variables
#
#
#
# * **Id/name:**  Identificador y nombre de la oferta.
#
# * **host_id/host_name:** Identificador y nombre del anfitrión.
#
# * **neighbourhood_group/neighbourhood:** Zona y barrio de la oferta. Cada zona es una agrupación de barrios.
# * **latitude/longitude:** Latitud y longitud de la oferta.
#
# * **room_type:** Que tipo de habitación se oferta. Puede ser el apartamento o casa entero, una habitación privada o una compartida.
#
# * **minimum_nights:**  Noches de estancia mínima.
#
# * **number_of_reviews:**  Número total de reviews de la oferta.
#
# * **last_review:**  Fecha de la última review hecha.
#
# * **reviews_per_month:** Número de reviews por mes. No siempre es entero y la mayoría son menos de 1.
#
# * **calculated_host_listings_count:** Cuantas habitaciones tiene el host en oferta.
#
# * **availability_365:** La disponibilidad de la oferta en un año: máximo de 365 (todo el año en oferta)
#
# * **price:** ¡Nuestro objetivo!. El precio de la oferta, en dolares.

# %% [markdown]
# ¿Es este un problema de regression o de classification? ¿Por que?:

# %% [markdown]
# 3. Antes de analizar el dataset, tenemos que transformar las fechas (la feature last_review) en algo con lo que podamos trabajar. Pandas tiene un data type específicamente para esto, datetime. Transforma last_review a formato datetime.

# %%
# Sólo con una línea de código
data["last_review"] = pd.to_datetime(data["last_review"])
data.info()
data.transpose().head(20)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32759 entries, 0 to 32758
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Unnamed: 0                      32759 non-null  int64
#  1   id                              32759 non-null  int64
#  2   name                            32755 non-null  object
#  3   host_id                         32759 non-null  int64
#  4   host_name                       32742 non-null  object
#  5   neighbourhood_group             32759 non-null  object
#  6   neighbourhood                   32759 non-null  object
#  7   latitude                        32759 non-null  float64
#  8   longitude                       32759 non-null  float64
#  9   room_type                       32759 non-null  object
#  10  minimum_nights                  32759 non-null  int64
#  11  number_of_reviews               32759 non-null  int64
#  12  last_review                     25987 non-null  datetime64[ns]
#  13  reviews_per_month               25987 non-null  float64
#  14  calculated_host_listings_count  32759 non-null  int64
#  15  availability_365                32759 non-null  int64
#  16  price                           32759 non-null  int64
# dtypes: datetime64[ns](1), float64(3), int64(8), object(5)
# memory usage: 4.2+ MB
#                                                0      \
# Unnamed: 0                                     35706
# id                                          28341280
# name                            Bushwick Rustic Loft
# host_id                                     10812370
# host_name                                         Al
# neighbourhood_group                         Brooklyn
# neighbourhood                               Bushwick
# latitude                                     40.6999
# longitude                                   -73.9182
# room_type                               Private room
# minimum_nights                                     1
# number_of_reviews                                 28
# last_review                      2019-07-07 00:00:00
# reviews_per_month                               2.75
# calculated_host_listings_count                     1
# availability_365                                  36
# price                                             69
#
#                                                               1      \
# Unnamed: 0                                                     2434
# id                                                          1213991
# name                            Private 2 bedroom Midtown Manhattan
# host_id                                                     6626827
# host_name                                                     Steve
# neighbourhood_group                                       Manhattan
# neighbourhood                                        Hell's Kitchen
# latitude                                                    40.7625
# longitude                                                  -73.9929
# room_type                                              Private room
# minimum_nights                                                    4
# number_of_reviews                                                77
# last_review                                     2019-06-19 00:00:00
# reviews_per_month                                              1.81
# calculated_host_listings_count                                    1
# availability_365                                                 21
# price                                                           240
#
#                                                        2      \
# Unnamed: 0                                             44725
# id                                                  34372753
# name                            Spacious Manhattan Apartment
# host_id                                             40038018
# host_name                                               Yves
# neighbourhood_group                                Manhattan
# neighbourhood                                        Midtown
# latitude                                             40.7615
# longitude                                           -73.9718
# room_type                                    Entire home/apt
# minimum_nights                                             5
# number_of_reviews                                          2
# last_review                              2019-06-09 00:00:00
# reviews_per_month                                          1
# calculated_host_listings_count                             1
# availability_365                                         132
# price                                                    449
#
#                                                                        3      \
# Unnamed: 0                                                             32341
# id                                                                  25311295
# name                            ★Modern,Cozy 3BDR/2BA Getaway in Upper East!
# host_id                                                             17896706
# host_name                                                               Mark
# neighbourhood_group                                                Manhattan
# neighbourhood                                                Upper East Side
# latitude                                                             40.7799
# longitude                                                           -73.9548
# room_type                                                    Entire home/apt
# minimum_nights                                                             4
# number_of_reviews                                                         58
# last_review                                              2019-06-18 00:00:00
# reviews_per_month                                                       4.26
# calculated_host_listings_count                                             1
# availability_365                                                         158
# price                                                                    399
#
#                                                                        4      \
# Unnamed: 0                                                              9648
# id                                                                   7411421
# name                            Hip & Trendy Williamsburg 2 BR 2BA Apartment
# host_id                                                              3750905
# host_name                                                              Louis
# neighbourhood_group                                                 Brooklyn
# neighbourhood                                                   Williamsburg
# latitude                                                              40.713
# longitude                                                           -73.9558
# room_type                                                    Entire home/apt
# minimum_nights                                                             2
# number_of_reviews                                                         28
# last_review                                              2019-06-22 00:00:00
# reviews_per_month                                                       0.61
# calculated_host_listings_count                                             1
# availability_365                                                         170
# price                                                                    109
#
#                                                               5      \
# Unnamed: 0                                                    44884
# id                                                         34447529
# name                            Cozy UWS Studio Near Riverside Park
# host_id                                                   260046126
# host_name                                                     Morad
# neighbourhood_group                                       Manhattan
# neighbourhood                                       Upper West Side
# latitude                                                    40.7896
# longitude                                                  -73.9794
# room_type                                           Entire home/apt
# minimum_nights                                                    1
# number_of_reviews                                                 2
# last_review                                     2019-06-30 00:00:00
# reviews_per_month                                              1.33
# calculated_host_listings_count                                    1
# availability_365                                                346
# price                                                           165
#
#                                                                            6      \
# Unnamed: 0                                                                 38355
# id                                                                      30205007
# name                            Quaint 1 bedroom tenement apartment in E.Village
# host_id                                                                 72326431
# host_name                                                                Brianna
# neighbourhood_group                                                    Manhattan
# neighbourhood                                                       East Village
# latitude                                                                 40.7257
# longitude                                                               -73.9884
# room_type                                                        Entire home/apt
# minimum_nights                                                                 2
# number_of_reviews                                                             11
# last_review                                                  2019-06-29 00:00:00
# reviews_per_month                                                           1.47
# calculated_host_listings_count                                                 1
# availability_365                                                             102
# price                                                                        100
#
#                                                           7      \
# Unnamed: 0                                                18184
# id                                                     14237346
# name                            Cozy room at Brooklyn&Breakfast
# host_id                                                  344035
# host_name                        Brooklyn&   Breakfast    -Len-
# neighbourhood_group                                    Brooklyn
# neighbourhood                                  Prospect Heights
# latitude                                                40.6782
# longitude                                              -73.9697
# room_type                                          Private room
# minimum_nights                                                1
# number_of_reviews                                           102
# last_review                                 2019-06-27 00:00:00
# reviews_per_month                                          2.98
# calculated_host_listings_count                               13
# availability_365                                            281
# price                                                        55
#
#                                                           8      \
# Unnamed: 0                                                12800
# id                                                      9775397
# name                            Apartment at the St.Regis Hotel
# host_id                                                50397134
# host_name                                              Masaichi
# neighbourhood_group                                   Manhattan
# neighbourhood                                           Midtown
# latitude                                                 40.761
# longitude                                              -73.9751
# room_type                                       Entire home/apt
# minimum_nights                                                1
# number_of_reviews                                             0
# last_review                                                 NaT
# reviews_per_month                                           NaN
# calculated_host_listings_count                                1
# availability_365                                              0
# price                                                      1200
#
#                                                      9      ...  \
# Unnamed: 0                                           37069  ...
# id                                                29472696  ...
# name                            Sharing room for FEMALE #1  ...
# host_id                                          167620568  ...
# host_name                                          Mikosya  ...
# neighbourhood_group                               Brooklyn  ...
# neighbourhood                               Brighton Beach  ...
# latitude                                           40.5806  ...
# longitude                                         -73.9631  ...
# room_type                                      Shared room  ...
# minimum_nights                                           1  ...
# number_of_reviews                                        4  ...
# last_review                            2019-06-09 00:00:00  ...
# reviews_per_month                                     0.56  ...
# calculated_host_listings_count                           2  ...
# availability_365                                       365  ...
# price                                                  100  ...
#
#                                                                 32749  \
# Unnamed: 0                                                      47191
# id                                                           35618939
# name                            NYC private room super clean and cozy
# host_id                                                      83132880
# host_name                                                    Alyandry
# neighbourhood_group                                            Queens
# neighbourhood                                                 Maspeth
# latitude                                                      40.7395
# longitude                                                     -73.895
# room_type                                                Private room
# minimum_nights                                                      1
# number_of_reviews                                                   0
# last_review                                                       NaT
# reviews_per_month                                                 NaN
# calculated_host_listings_count                                      4
# availability_365                                                  304
# price                                                              56
#
#                                                                       32750  \
# Unnamed: 0                                                            21962
# id                                                                 17669480
# name                            Sunny Brownstone Studio in BedStuy Brooklyn
# host_id                                                           112814443
# host_name                                                             Jamal
# neighbourhood_group                                                Brooklyn
# neighbourhood                                            Bedford-Stuyvesant
# latitude                                                            40.6822
# longitude                                                          -73.9462
# room_type                                                   Entire home/apt
# minimum_nights                                                            2
# number_of_reviews                                                       104
# last_review                                             2019-06-12 00:00:00
# reviews_per_month                                                      3.69
# calculated_host_listings_count                                            1
# availability_365                                                        268
# price                                                                   125
#
#                                                                32751  \
# Unnamed: 0                                                     37194
# id                                                          29547314
# name                            Apartment New York \nHell’s Kitchens
# host_id                                                     35303743
# host_name                                                   Patricia
# neighbourhood_group                                        Manhattan
# neighbourhood                                        Upper West Side
# latitude                                                     40.7683
# longitude                                                   -73.9837
# room_type                                               Private room
# minimum_nights                                                    30
# number_of_reviews                                                  0
# last_review                                                      NaT
# reviews_per_month                                                NaN
# calculated_host_listings_count                                     1
# availability_365                                                  97
# price                                                           6500
#
#                                                             32752  \
# Unnamed: 0                                                  16850
# id                                                       13431257
# name                            Luxurious 1BR Apt in Midtown West
# host_id                                                  30283594
# host_name                                                    Kara
# neighbourhood_group                                     Manhattan
# neighbourhood                                      Hell's Kitchen
# latitude                                                   40.761
# longitude                                                -73.9975
# room_type                                         Entire home/apt
# minimum_nights                                                 30
# number_of_reviews                                               0
# last_review                                                   NaT
# reviews_per_month                                             NaN
# calculated_host_listings_count                                121
# availability_365                                              365
# price                                                         239
#
#                                                      32753  \
# Unnamed: 0                                            6265
# id                                                 4576206
# name                            Brooklyn Brownstone Beauty
# host_id                                           22017065
# host_name                                    Marycatherine
# neighbourhood_group                               Brooklyn
# neighbourhood                             Prospect Heights
# latitude                                           40.6814
# longitude                                         -73.9708
# room_type                                  Entire home/apt
# minimum_nights                                           3
# number_of_reviews                                       27
# last_review                            2019-07-05 00:00:00
# reviews_per_month                                     0.49
# calculated_host_listings_count                           1
# availability_365                                       266
# price                                                  250
#
#                                                    32754  \
# Unnamed: 0                                         11284
# id                                               8754339
# name                            Gran Fondo Cyclist Haven
# host_id                                         20261309
# host_name                                          Sarah
# neighbourhood_group                            Manhattan
# neighbourhood                         Washington Heights
# latitude                                         40.8465
# longitude                                       -73.9432
# room_type                                    Shared room
# minimum_nights                                         1
# number_of_reviews                                      0
# last_review                                          NaT
# reviews_per_month                                    NaN
# calculated_host_listings_count                         1
# availability_365                                       0
# price                                                 60
#
#                                                                     32755  \
# Unnamed: 0                                                          44732
# id                                                               34383329
# name                            A private bedroom in Chelsea , Manhattan.
# host_id                                                          53254710
# host_name                                                          Aamito
# neighbourhood_group                                             Manhattan
# neighbourhood                                                     Chelsea
# latitude                                                          40.7396
# longitude                                                        -74.0008
# room_type                                                    Private room
# minimum_nights                                                          2
# number_of_reviews                                                       4
# last_review                                           2019-06-30 00:00:00
# reviews_per_month                                                     1.9
# calculated_host_listings_count                                          1
# availability_365                                                       76
# price                                                                  85
#
#                                                                             32756  \
# Unnamed: 0                                                                  38158
# id                                                                       30109697
# name                            Nicely appointed BIG one bedroom off Central Park
# host_id                                                                   1385157
# host_name                                                                   Brian
# neighbourhood_group                                                     Manhattan
# neighbourhood                                                     Upper West Side
# latitude                                                                  40.7832
# longitude                                                                -73.9737
# room_type                                                         Entire home/apt
# minimum_nights                                                                 30
# number_of_reviews                                                               1
# last_review                                                   2019-04-12 00:00:00
# reviews_per_month                                                            0.34
# calculated_host_listings_count                                                  5
# availability_365                                                              261
# price                                                                         130
#
#                                                            32757  \
# Unnamed: 0                                                   860
# id                                                        304799
# name                            Penthouse Studio by Central Park
# host_id                                                   185753
# host_name                                                Carolyn
# neighbourhood_group                                    Manhattan
# neighbourhood                                    Upper West Side
# latitude                                                 40.7751
# longitude                                               -73.9799
# room_type                                        Entire home/apt
# minimum_nights                                                 2
# number_of_reviews                                             11
# last_review                                  2019-06-09 00:00:00
# reviews_per_month                                           0.13
# calculated_host_listings_count                                 1
# availability_365                                               2
# price                                                        150
#
#                                                         32758
# Unnamed: 0                                              15795
# id                                                   12775106
# name                            Apartment NYC - 10 to 20 June
# host_id                                               1722054
# host_name                                            Cristian
# neighbourhood_group                                    Queens
# neighbourhood                                Long Island City
# latitude                                              40.7466
# longitude                                            -73.9455
# room_type                                     Entire home/apt
# minimum_nights                                              5
# number_of_reviews                                           1
# last_review                               2016-06-19 00:00:00
# reviews_per_month                                        0.03
# calculated_host_listings_count                              1
# availability_365                                            0
# price                                                     120
#
# [17 rows x 32759 columns]

# %% [markdown]
# 4. Para analizar los datos también necesitamos saber cuanta información nos falta. Utiliza isnull() para averiguar a que feature le faltan mas datos.

# %%
# Sólo con una línea de código
data.isnull().sum()
# Out:
# Unnamed: 0                           0
# id                                   0
# name                                 4
# host_id                              0
# host_name                           17
# neighbourhood_group                  0
# neighbourhood                        0
# latitude                             0
# longitude                            0
# room_type                            0
# minimum_nights                       0
# number_of_reviews                    0
# last_review                       6772
# reviews_per_month                 6772
# calculated_host_listings_count       0
# availability_365                     0
# price                                0
# dtype: int64

# %% [markdown]
# 5. Finalmente, solo nos falta deshacernos de las features que solo sirven de identificador y no ayudan a predecir.

# %%
# Sólo con una línea de código
data = data.drop(['Unnamed: 0', 'id','name','host_id','host_name'], axis=1)

# %% [markdown]
# 6. ¡Todo listo! Ya podemos analizar la distribución de los datos con la función .describe()

# %%
# Sólo con una línea de código
data.describe()
# Out:
#          Unnamed: 0      latitude     longitude  minimum_nights  \
# count  32759.000000  32759.000000  32759.000000    32759.000000
# mean   24488.977350     40.728968    -73.952465        7.131475
# std    14106.247295      0.054479      0.045704       21.236959
# min        2.000000     40.499790    -74.240840        1.000000
# 25%    12270.500000     40.690150    -73.983130        1.000000
# 50%    24455.000000     40.723180    -73.955800        3.000000
# 75%    36745.500000     40.763155    -73.936540        5.000000
# max    48894.000000     40.913060    -73.712990     1250.000000
#
#        number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# count       32759.000000       25987.000000                    32759.000000
# mean           23.240911           1.383150                        7.223175
# std            44.354050           1.699714                       33.275291
# min             0.000000           0.010000                        1.000000
# 25%             1.000000           0.190000                        1.000000
# 50%             5.000000           0.730000                        1.000000
# 75%            24.000000           2.030000                        2.000000
# max           607.000000          58.500000                      327.000000
#
#        availability_365         price
# count      32759.000000  32759.000000
# mean         113.116090    154.312983
# std          131.687842    256.571284
# min            0.000000      0.000000
# 25%            0.000000     69.000000
# 50%           45.000000    107.000000
# 75%          226.000000    178.000000
# max          365.000000  10000.000000

# %% [markdown]
# ### Limpiar y normalizar la información del dataset
# ![texto alternativo](https://i.imgur.com/8u4xTI7.png)
#
# Este dataset contiene información incompleta que debemos rellenar para poder usarla a la hora de predecir el precio de las ofertas.
# También tenemos que transformar last_review si queremos incluirla en la predicción (no podemos utilizar una fecha como input directamente).
#
# Para esta limpieza usaremos varias funciones de Pandas. Aquí teneis una [pista](https://new.paradigmadigital.com/wp-content/uploads/2019/02/Pandas_cheatsheet.pdf).

# %% [markdown]
# 7. Encuentra el número de ofertas que por no tener reviews no tienen información en las columnas de last_review y reviews_per_month.

# %%
# Sólo con una línea de código
data.last_review.isnull().sum()
# Out:
# 6772

# %% [markdown]
# 8. Tenemos que completar esta información si no queremos eliminar el resto del ejemplo. Rellena todos los NaNs de las reviews_per_month con 0 (Completaremos la columna de last_review después).

# %%
# Sólo con una línea de código 

data.reviews_per_month = data.reviews_per_month.fillna(0)
data.reviews_per_month.isnull().sum()
# Out:
# 0

# %% [markdown]
# 9. Vamos a transformar la variable last_review. Es una fecha, lo cual nos hace dificil trabajar con ella. Vamos primero a completar los ejemplos que no tienen una última fecha. Reemplaza estos NaNs con la primera review histórica del dataset.

# %%
# Dos lineas de código 
data.last_review = data.last_review.fillna(data.last_review.min())
data.last_review.isnull().sum()
# Out:
# 0

# %% [markdown]
# 10. Ahora que no tenemos valores vacios podemos cambiar la variable last_review a algo mas util. Buscamos que valores mas pequeños correspondan a reviews antiguas o que no hayan tenido ninguna, mientras que valores mas grandes correspondan a reviews mas recientes.
#
# Podemos utilizar la función toordinal() para hayar el número de dias que han transcurrido desde el dia 1 del año 1, pero esos siguen siendo números demasiado grandes que no siguen la distribución que buscamos.
#
# Consigue que last_reviews pase a representar la cantidad de dias que han transcurrido desde que se hizo la primera review histórica.

# %%
# Solo una línea de código
data.last_review = (data.last_review - data.last_review.min()).apply(lambda x: x.days)
data.transpose().head(20)
# Out:
#                                        0               1                2      \
# Unnamed: 0                             35706            2434            44725
# neighbourhood_group                 Brooklyn       Manhattan        Manhattan
# neighbourhood                       Bushwick  Hell's Kitchen          Midtown
# latitude                             40.6999         40.7625          40.7615
# longitude                           -73.9182        -73.9929         -73.9718
# room_type                       Private room    Private room  Entire home/apt
# minimum_nights                             1               4                5
# number_of_reviews                         28              77                2
# last_review                             2995            2977             2967
# reviews_per_month                       2.75            1.81                1
# calculated_host_listings_count             1               1                1
# availability_365                          36              21              132
# price                                     69             240              449
#
#                                           3                4      \
# Unnamed: 0                                32341             9648
# neighbourhood_group                   Manhattan         Brooklyn
# neighbourhood                   Upper East Side     Williamsburg
# latitude                                40.7799           40.713
# longitude                              -73.9548         -73.9558
# room_type                       Entire home/apt  Entire home/apt
# minimum_nights                                4                2
# number_of_reviews                            58               28
# last_review                                2976             2980
# reviews_per_month                          4.26             0.61
# calculated_host_listings_count                1                1
# availability_365                            158              170
# price                                       399              109
#
#                                           5                6      \
# Unnamed: 0                                44884            38355
# neighbourhood_group                   Manhattan        Manhattan
# neighbourhood                   Upper West Side     East Village
# latitude                                40.7896          40.7257
# longitude                              -73.9794         -73.9884
# room_type                       Entire home/apt  Entire home/apt
# minimum_nights                                1                2
# number_of_reviews                             2               11
# last_review                                2988             2987
# reviews_per_month                          1.33             1.47
# calculated_host_listings_count                1                1
# availability_365                            346              102
# price                                       165              100
#
#                                            7                8      \
# Unnamed: 0                                 18184            12800
# neighbourhood_group                     Brooklyn        Manhattan
# neighbourhood                   Prospect Heights          Midtown
# latitude                                 40.6782           40.761
# longitude                               -73.9697         -73.9751
# room_type                           Private room  Entire home/apt
# minimum_nights                                 1                1
# number_of_reviews                            102                0
# last_review                                 2985                0
# reviews_per_month                           2.98                0
# calculated_host_listings_count                13                1
# availability_365                             281                0
# price                                         55             1200
#
#                                          9      ...         32749  \
# Unnamed: 0                               37069  ...         47191
# neighbourhood_group                   Brooklyn  ...        Queens
# neighbourhood                   Brighton Beach  ...       Maspeth
# latitude                               40.5806  ...       40.7395
# longitude                             -73.9631  ...       -73.895
# room_type                          Shared room  ...  Private room
# minimum_nights                               1  ...             1
# number_of_reviews                            4  ...             0
# last_review                               2967  ...             0
# reviews_per_month                         0.56  ...             0
# calculated_host_listings_count               2  ...             4
# availability_365                           365  ...           304
# price                                      100  ...            56
#
#                                              32750            32751  \
# Unnamed: 0                                   21962            37194
# neighbourhood_group                       Brooklyn        Manhattan
# neighbourhood                   Bedford-Stuyvesant  Upper West Side
# latitude                                   40.6822          40.7683
# longitude                                 -73.9462         -73.9837
# room_type                          Entire home/apt     Private room
# minimum_nights                                   2               30
# number_of_reviews                              104                0
# last_review                                   2970                0
# reviews_per_month                             3.69                0
# calculated_host_listings_count                   1                1
# availability_365                               268               97
# price                                          125             6500
#
#                                           32752             32753  \
# Unnamed: 0                                16850              6265
# neighbourhood_group                   Manhattan          Brooklyn
# neighbourhood                    Hell's Kitchen  Prospect Heights
# latitude                                 40.761           40.6814
# longitude                              -73.9975          -73.9708
# room_type                       Entire home/apt   Entire home/apt
# minimum_nights                               30                 3
# number_of_reviews                             0                27
# last_review                                   0              2993
# reviews_per_month                             0              0.49
# calculated_host_listings_count              121                 1
# availability_365                            365               266
# price                                       239               250
#
#                                              32754         32755  \
# Unnamed: 0                                   11284         44732
# neighbourhood_group                      Manhattan     Manhattan
# neighbourhood                   Washington Heights       Chelsea
# latitude                                   40.8465       40.7396
# longitude                                 -73.9432      -74.0008
# room_type                              Shared room  Private room
# minimum_nights                                   1             2
# number_of_reviews                                0             4
# last_review                                      0          2988
# reviews_per_month                                0           1.9
# calculated_host_listings_count                   1             1
# availability_365                                 0            76
# price                                           60            85
#
#                                           32756            32757  \
# Unnamed: 0                                38158              860
# neighbourhood_group                   Manhattan        Manhattan
# neighbourhood                   Upper West Side  Upper West Side
# latitude                                40.7832          40.7751
# longitude                              -73.9737         -73.9799
# room_type                       Entire home/apt  Entire home/apt
# minimum_nights                               30                2
# number_of_reviews                             1               11
# last_review                                2909             2967
# reviews_per_month                          0.34             0.13
# calculated_host_listings_count                5                1
# availability_365                            261                2
# price                                       130              150
#
#                                            32758
# Unnamed: 0                                 15795
# neighbourhood_group                       Queens
# neighbourhood                   Long Island City
# latitude                                 40.7466
# longitude                               -73.9455
# room_type                        Entire home/apt
# minimum_nights                                 5
# number_of_reviews                              1
# last_review                                 1882
# reviews_per_month                           0.03
# calculated_host_listings_count                 1
# availability_365                               0
# price                                        120
#
# [13 rows x 32759 columns]

# %% [markdown]
# 11. Para visualizar la distribución de las fechas, genera una gráfica que muestre la variable last_reviews.

# %%
# Solo una línea de código
sns.distplot(data.last_review, bins=50)

# %% [markdown]
# Parece que hay dos grupos muy distinguidos. ¿A que se debe esta distribución?:
#
# **R: Porque hay un grupo significativo al que no se ha llamado**

# %% [markdown]
# #### Estudio de la variable a predecir y eliminación de ruido

# %% [markdown]
# 12. A la hora de predecir el precio, es mucho mas favorable si primero transformamos y analizamos la variable que buscamos para hacerla mas facil de predecir.
#
# Primero, vamos a ver como el precio de las ofertas está distribuido. Genera una gráfica que muestre el precio de las ofertas. Aquí tienes una [Pista](https://seaborn.pydata.org/generated/seaborn.distplot.html).

# %%
# Solo una línea de código.
sns.distplot(data.price, bins=50)

# %% [markdown]
# Tenemos una variable que sigue una distribución log-normal. Podemos transformarla en una distribución normal aplicando log1p(), una función que responde a la siguiente ecuación:
#
# $ y = log(x+1) $
#
# Esto hace que el precio sea mas facil de predecir, al tener una distribución normal.

# %% [markdown]
# 13. Vamos a visualizar esta transformación. Genera otra gráfica de price tras aplicar la función log1p().

# %%
#Solo una línea de código
sns.distplot(np.log1p(data.price), bins=50)

# %% [markdown]
# Ahora tenemos una distribución mucho mas apropiada para hacer predicciones. Sin embargo, todavía quedan muchos outliers que añaden ruido a la muestra.

# %% [markdown]
# 14. ¿Por encima y debajo de qué valores esta presente este ruido?. Elimina del dataframe aquellos valores que no entren en la distribución normal.

# %%
#Dos lineas de código
data = data.drop(data[np.log1p(data.price) > 8].index)
data = data.drop(data[np.log1p(data.price) < 2].index)

# %% [markdown]
# 14. Ahora, vuelve a generar la gráfica de precio y log1p del precio (usa el mismo código que antes, o ponlo en un [subplot](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.subplots.html)).

# %%
#Solo una línea de código
sns.distplot(np.log1p(data.price), bins=50)

# %% [markdown]
# 15. Finalmente, tenemos una variable de salida normalizada y sin ruido que mejorará nuestras predicciones. Cambia la variable price por el log1p de price.

# %%
#Solo una línea de código
data.price = np.log1p(data.price)

# %% [markdown]
# #### Exploración de variables

# %% [markdown]
# Vamos a explorar un poco mas el resto de variables que pueden afectar al precio de una oferta.

# %% [markdown]
# 16. Empecemos por crear un histograma de las distintas zonas de la ciudad y la cantidad de ofertas en cada una de ellas (a lo mejor necesitas ampliar el gráfico)

# %%
#Tres lineas de código
plt.figure(figsize=(15,9))
for neighbourhood in data['neighbourhood_group'].unique():
    print(neighbourhood, len(data[data.neighbourhood_group==neighbourhood]))
    sns.distplot(data[data.neighbourhood_group==neighbourhood].price, bins=50,label=neighbourhood)
plt.legend()
# Out:
# Brooklyn 13457
# Manhattan 14556
# Queens 3719
# Bronx 731
# Staten Island 242

# %% [markdown]
# 17. Ahora crea un mapa de los apartamentos ofertados con la latitud y longitud (puntos extra si los coloreas por zonas o barrios). Lo mejor es hacerlo en un subplot y así puedes controlar el tamaño del mapa.

# %%
#Dos lineas de código
plt.figure(figsize=(15,9))
sns.scatterplot(data=data, x="latitude", y="longitude",hue="neighbourhood_group")

# %% [markdown]
# 18. Vamos ahora a generar otro histograma, esta vez con el tipo de habitación ofertado (También es buena idea ajustar el tamaño de la gráfica).

# %%
#Tres lineas de código
plt.figure(figsize=(15,9))
for roomType in data['room_type'].unique():
    print(roomType, len(data[data.room_type==roomType]))
    sns.distplot(data[data.room_type==roomType].price, bins=33,label=roomType)
plt.legend()
# Out:
# Private room 14919
# Entire home/apt 17001
# Shared room 785

# %% [markdown]
# #### Transformación de variables

# %% [markdown]
# Podemos aplicar el mismo proceso que le aplicamos a la variable price a nuestras variables de entrada y así conseguir una distribución mas cómoda para los métodos de busqueda.
#
# 19. Aplica la transformación log1p() a minimum_nights, generando las gráficas antes y despues y compáralas.

# %%
#Tres lineas de código
fig, axs = plt.subplots(2,figsize=(15,9))
axs[0].hist(data.minimum_nights,bins=100)
axs[0].title.set_text('data.minimum_nights')
axs[1].hist(data.minimum_nights.apply(lambda x: np.log1p(x)),bins=100,color="g")
axs[1].title.set_text('np.log1p(data.minimum_nights)')

# %% [markdown]
# 20. Finalmente, guarda minimum_nights como log1p de minimum_nights
#
# **R: sí parece relevante la transformación**

# %%
#Solo una línea de código.
data.minimum_nights=np.log1p(data.minimum_nights)

# %% [markdown]
# 21. Repite el proceso, esta vez con reviews_per_month. ¿Es relevante la transformación?

# %%
#Tres lineas de código.
fig, axs = plt.subplots(2,figsize=(15,9))
axs[0].hist(data.reviews_per_month,bins=100)
axs[0].title.set_text('data.reviews_per_month')
axs[1].hist(data.reviews_per_month.apply(lambda x: np.log1p(x)),bins=100,color="g")
axs[1].title.set_text('np.log1p(data.reviews_per_month)')
data.reviews_per_month=np.log1p(data.reviews_per_month)

# %% [markdown]
# #### Estudio de la disponibilidad en número de dias (0,365)

# %% [markdown]
# 22. Vamos a empezar representando la disponibilidad en un distplot(). Como conocemos los limites de esta variable, lo mejor es limitar el intervalo de la gráfica y hacerla mas grande.

# %%
#Cuatro lineas de código.
fig, ax = plt.subplots(figsize=(15,6))
ax.set_xlim(0,365)
sns.distplot(data.availability_365, bins=100)
plt.show()

# %% [markdown]
# #### Añadir variables artificiales

# %% [markdown]
# Se ha visto en el scatterplot anterior que parece haber dos grupos, uno disponible la mayor parte del año y otro solo unos pocos dias.
#
# También se intuye que aquellos sitios que no tengan reviews... Como que no dan mucha confi no? ;)

# %% [markdown]
# 23. Añade tres categorias que midan si el apartamento está disponible todo el año, si su disponibilidad es muy baja (menor de 12 dias al año), y si no tiene reviews.

# %%
#Tres lineas de código
data['available_always'] = np.where(data.availability_365==365,1,0)
data['available_low'] = np.where(data.availability_365<12,1,0)
data['reviews_empty'] = np.where(data.number_of_reviews==0,1,0)

data.isnull().sum()
# Out:
# Unnamed: 0                        0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# price                             0
# available_always                  0
# available_low                     0
# reviews_empty                     0
# dtype: int64

# %% [markdown]
# 24. Vamos a generar un heatmap que muestre la relación entre todas las variables de entrada y price. Utiliza corr() y la función heatmap() de seaborn.

# %%
#Tres lineas de código
plt.figure(figsize = (15,15))
corr = data.corr()
sns.heatmap(corr,annot=True)

# %% [markdown]
# #### Pasar variables categóricas a one_hot

# %% [markdown]
# 25. Para hacer las features categóricas mas fáciles de interpretar por el modelo, vamos a transformarlas en un OneHotEncoding. Utiliza la función get_dummies() de pandas (te deberían de quedar 241 columnas)

# %%
#Dos lineas de código
data_with_dummies = pd.get_dummies(data=data)

# %% [markdown]
# # Modelos, modelos, modelos

# %% [markdown]
# Hecha toda la exploración, análisis y limpieza de datos, pasamos a la parte divertida: ¡Los modelos!
#
# Empezamos importando todas las clases que vamos a necesitar para encontrar un buen modelo predictivo:

# %%
from sklearn.model_selection import train_test_split,cross_val_score,  GridSearchCV, KFold, StratifiedKFold, RandomizedSearchCV
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# 26. Divide el dataset en X_train, X_test, y_train y y_test utilizando train_test_split(). No te olvides de no incluir price en el training set.

# %%
#Tres lineas de código
label = data_with_dummies.price
X_train, X_test, y_train, y_test = train_test_split(data_with_dummies, label, test_size = 0.2, random_state = 50)

# %% [markdown]
# 27. Vamos a utilizar cross_validation para entrenar nuesto modelo, utilizando Kfold para hayar la score. Implementa un Kfold que realize 5 splits y calcula el error medio y la desviación de un RandomForestRegressor sin cambiar sus parámetros (todavía). [Pista](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.KFold.html).

# %%
#Tres lineas de código

# %% [markdown]
# 28. Al utilizar un RandomForestRegressor, ¿que hiperparámetros estabamos utilizando?. Lista todos los parámetros que utiliza este modelo (utiliza la función get_params() y la librería pprint)

# %%
from pprint import pprint
#Dos lineas de código

# %% [markdown]
# Podemos ajustar todos estos paámetros para mejorar la exactitud de nuestro modelo. Una forma de encontrar qué combinación funciona mejor es utilizar un GridSearchCV, que prueba modelos con muchas combinaciones distintas y calcula su score para encontrar el mejor modelo a fuerza bruta. Para esto, hay que pasar una lista de valores para cada parámetro, y GridSearchCV probará con todos. [Mas información](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html).

# %% [markdown]
# 29. Delimita que valores quieres que cada parámetro tenga, y incluye cada una de estas listas en un diccionario para poder ejecutar el GridSearchCV. Ten en cuenta los valores posibles para cada uno de los parámetros.

# %%
# 8 lineas de código

# %% [markdown]
# 30. Ahora ya podemos implementar un GridSearchCV. Para hacerlo mas rápido, se utiliza una versión que no prueba con todas las combinaciones posibles, sino con unas cuantas de forma aleatorias.(de ahí su nombre, RandomizedSearchCV). Implementalo, teniendo en cuenta que tiene como parametros el modelo a ajustar y el diccionario que hemos definido antes, entre otros. Este paso puede durar unos minutos, ya que tiene que ajustar muchos modelos para encontrar el mejor. Aquí está la [documentación](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.RandomizedSearchCV.html) del RandomizedSearchCV.

# %%
#Dos lineas de código

# %% [markdown]
# 31. Para terminar, encuentra el mean squared error y $R^2$ del mejor modelo que hallas creado.

# %%
#Seis lineas de código

# %% [markdown]
# Ahora, ¡a mejorar esa score!
# Puedes probar a:
# - Eliminar features que no sean relevantes para la predicción
# - Implementar Gradient boosting utilizando XBoost o Adaboost, entre otros
# - Ajustar los hiperparámetros manualmente para llegar a mejores modelos
# - Utilizar un Tree Interpreter para ver qué árboles de decisión tienen mas importancia

# %% [markdown]
# Al acabar el challenge, os daremos un validation set para ver que grupo ha conseguido la mejor score. ¡Quien gane tiene premio!
